# %%
import pandas as pd
import io

# %%
euro12 = pd.read_csv("C:\\Users\\Nishi\\Desktop\\chipotle1.tsv",sep = '\t')

# %%
euro12
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
# clean the item_price column and transform it in a float
prices = [float(value[1 : -1]) for value in euro12.item_price]

# %%
# reassign the column with the cleaned prices
euro12.item_price = prices

# %%
# delete the duplicates in item_name and quantity
chipo_filtered = euro12.drop_duplicates(['item_name','quantity','choice_description'])

# %%
chipo_filtered
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
# select only the products with quantity equals to 1
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]

# %%
chipo_one_prod
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# 16           8         1                        Chicken Burrito
# ...

# %%
chipo_one_prod[chipo_one_prod['item_price']>10].item_name.nunique()
# Out:
# 25

# %%
chipo_one_prod[chipo_one_prod['item_price']>10]
# Out:
#       order_id  quantity           item_name  \
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# 39          19         1       Barbacoa Bowl
# 42          20         1        Chicken Bowl
# 43          20         1       Steak Burrito
# 45          21         1     Chicken Burrito
# 52          24         1     Chicken Burrito
# 57          26         1      Veggie Burrito
# 62          28         1         Veggie Bowl
# 79          35         1  Chicken Soft Tacos
# 90          40         1          Steak Bowl
# 91          40         1          Steak Bowl
# 93          41         1    Carnitas Burrito
# 97          43         1       Carnitas Bowl
# 123         54         1        Chicken Bowl
# 130         57         1    Barbacoa Burrito
# 134         59         1     Chicken Burrito
# 136         61         1       Barbacoa Bowl
# ...

# %%
chipo_one_prod.query('price_per_item > 10').item_name.nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\DATA_SCIENCE\Anaconda_Softwaer\zzz\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     180             if self.has_resolvers:
# --> 181                 return self.resolvers[key]
#     182
#
# F:\DATA_SCIENCE\Anaconda_Softwaer\zzz\lib\collections\__init__.py in __getitem__(self, key)
#     913                 pass
# --> 914         return self.__missing__(key)            # support subclasses that define __missing__
#     915
#
# F:\DATA_SCIENCE\Anaconda_Softwaer\zzz\lib\collections\__init__.py in __missing__(self, key)
#     905     def __missing__(self, key):
# --> 906         raise KeyError(key)
#     907
#
# KeyError: 'price_per_item'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# delete the duplicates in item_name and quantity
chipo_filtered = euro12.drop_duplicates(['item_name','quantity'])

# %%
euro12[(euro12['item_name'] == 'Chicken Bowl') & (euro12['quantity'] == 1)]
# Out:
#       order_id  quantity     item_name  \
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# 110         49         1  Chicken Bowl
# 123         54         1  Chicken Bowl
# 138         62         1  Chicken Bowl
# 140         63         1  Chicken Bowl
# 142         64         1  Chicken Bowl
# 160         73         1  Chicken Bowl
# 176         79         1  Chicken Bowl
# 182         82         1  Chicken Bowl
# 193         86         1  Chicken Bowl
# 199         89         1  Chicken Bowl
# 206         92         1  Chicken Bowl
# 209         93         1  Chicken Bowl
# 211         93         1  Chicken Bowl
# 218         96         1  Chicken Bowl
# 220         97         1  Chicken Bowl
# ...

# %%
# select only the products with quantity equals to 1
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]

# %%
# select only the item_name and item_price columns
price_per_item = chipo_one_prod[['item_name', 'item_price']]

# %%
# sort the values from the most to less expensive
price_per_item.sort_values(by = "item_price", ascending = False).head(20)
# Out:
#                   item_name  item_price
# 606        Steak Salad Bowl       11.89
# 1229    Barbacoa Salad Bowl       11.89
# 1132    Carnitas Salad Bowl       11.89
# 7             Steak Burrito       11.75
# 168   Barbacoa Crispy Tacos       11.75
# 39            Barbacoa Bowl       11.75
# 738       Veggie Soft Tacos       11.25
# 186       Veggie Salad Bowl       11.25
# 62              Veggie Bowl       11.25
# 57           Veggie Burrito       11.25
# 250           Chicken Salad       10.98
# 5              Chicken Bowl       10.98
# 8          Steak Soft Tacos        9.25
# 554   Carnitas Crispy Tacos        9.25
# 237     Carnitas Soft Tacos        9.25
# 56      Barbacoa Soft Tacos        9.25
# 92       Steak Crispy Tacos        9.25
# 664             Steak Salad        8.99
# 54               Steak Bowl        8.99
# 3750         Carnitas Salad        8.99

# %%
#Sort by the name of the item


# OR

euro12.sort_values(by = "item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# 3422      1373         1  6 Pack Soft Drink
# 553        230         1  6 Pack Soft Drink
# 1916       774         1  6 Pack Soft Drink
# 1922       776         1  6 Pack Soft Drink
# 1937       784         1  6 Pack Soft Drink
# 3836      1537         1  6 Pack Soft Drink
# 298        129         1  6 Pack Soft Drink
# 1976       798         1  6 Pack Soft Drink
# 1167       481         1  6 Pack Soft Drink
# 3875      1554         1  6 Pack Soft Drink
# 1124       465         1  6 Pack Soft Drink
# 3886      1558         1  6 Pack Soft Drink
# 2108       849         1  6 Pack Soft Drink
# 3010      1196         1  6 Pack Soft Drink
# 4535      1803         1  6 Pack Soft Drink
# ...

# %%
euro12.item_name.sort_values()
# Out:
# 3389    6 Pack Soft Drink
# 341     6 Pack Soft Drink
# 1849    6 Pack Soft Drink
# 1860    6 Pack Soft Drink
# 2713    6 Pack Soft Drink
# 3422    6 Pack Soft Drink
# 553     6 Pack Soft Drink
# 1916    6 Pack Soft Drink
# 1922    6 Pack Soft Drink
# 1937    6 Pack Soft Drink
# 3836    6 Pack Soft Drink
# 298     6 Pack Soft Drink
# 1976    6 Pack Soft Drink
# 1167    6 Pack Soft Drink
# 3875    6 Pack Soft Drink
# 1124    6 Pack Soft Drink
# 3886    6 Pack Soft Drink
# 2108    6 Pack Soft Drink
# 3010    6 Pack Soft Drink
# 4535    6 Pack Soft Drink
# 4169    6 Pack Soft Drink
# 4174    6 Pack Soft Drink
# 4527    6 Pack Soft Drink
# 4522    6 Pack Soft Drink
# 3806    6 Pack Soft Drink
# 2389    6 Pack Soft Drink
# 3132    6 Pack Soft Drink
# 3141    6 Pack Soft Drink
# 639     6 Pack Soft Drink
# 1026    6 Pack Soft Drink
#               ...
# 2996         Veggie Salad
# 3163         Veggie Salad
# 4084         Veggie Salad
# 1694         Veggie Salad
# 2756         Veggie Salad
# ...

# %%
#Step 7. What was the quantity of the most expensive item ordered?
euro12.sort_values(by = "item_price", ascending = False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
#step 8. How many times was a Veggie Salad Bowl ordered?

chipo_salad = euro12[euro12.item_name == "Veggie Salad Bowl"]

len(chipo_salad)
# Out:
# 18

# %%
#Step 9. How many times did someone order more than one Canned Soda?
chipo_drink_steak_bowl = euro12[(euro12.item_name == "Canned Soda") & (euro12.quantity > 1)]
len(chipo_drink_steak_bowl)
# Out:
# 20
